# %%
import matplotlib.pyplot as plt
from numpy import loadtxt

lines = loadtxt("D:\\test.txt", comments="#", delimiter=",", unpack=False)
plt.plot(lines)
plt.ylabel('some numbers')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.show()
